# %%
from scapy.all import *

# Ethernet frame
eth_frame = Ether(dst="ff:ff:ff:ff:ff:ff", src="00:11:22:33:44:55", type=0x0806)

print ("Ethernet frame: ")
eth_frame.show()
# Out:
# Ethernet frame:
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = 00:11:22:33:44:55
#   type      = ARP

# %%
# ARP request
arp_request = ARP(pdst="192.168.1.1", psrc="192.168.1.100",op=1)

print ("ARP Request: ")
arp_request.show()
# Out:
# ARP Request:
# ###[ ARP ]###
#   hwtype    = Ethernet (10Mb)
#   ptype     = IPv4
#   hwlen     = None
#   plen      = None
#   op        = who-has
#   hwsrc     = 8a:cf:75:23:fb:40
#   psrc      = 192.168.1.100
#   hwdst     = 00:00:00:00:00:00
#   pdst      = 192.168.1.1

# %% [markdown]
# This two upcoming code cells needs to be run as root (sudo)

# %%
# Create an ethernet frame with an arp request
eth_arp_packet = Ether (dst="ff:ff:ff:ff:ff:ff")/ARP(pdst="192.168.1.1")

print ("Ethernet + ARP request: ")
eth_arp_packet.show()
# Out:
# Ethernet + ARP request:
# ###[ Ethernet ]###
#   dst       = ff:ff:ff:ff:ff:ff
#   src       = 8a:cf:75:23:fb:40
#   type      = ARP
# ###[ ARP ]###
#      hwtype    = Ethernet (10Mb)
#      ptype     = IPv4
#      hwlen     = None
#      plen      = None
#      op        = who-has
#      hwsrc     = 8a:cf:75:23:fb:40
#      psrc      = 10.80.43.174
#      hwdst     = 00:00:00:00:00:00
#      pdst      = 192.168.1.1

# %%
# send an ARP request on the network

eth_arp_packet = Ether (dst="ff:ff:ff:ff:ff:ff")/ARP(pdst="10.80.1.1")

response = srp1(eth_arp_packet, timeout=2, verbose =False)

if response:
    print ("Received Response: ")
    response.show()
else: 
    print("No response received.")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[9], line 5
#       1 # send an ARP request on the network
#       3 eth_arp_packet = Ether (dst="ff:ff:ff:ff:ff:ff")/ARP(pdst="10.80.1.1")
# ----> 5 response = srp1(eth_arp_packet, timeout=2, verbose =False)
#       7 if response:
#       8     print ("Received Response: ")
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/sendrecv.py:769, in srp1(*args, **kargs)
#     763 @conf.commands.register
#     764 def srp1(*args, **kargs):
#     765     # type: (*Any, **Any) -> Optional[Packet]
#     766     """
#     767     Send and receive packets at layer 2 and return only the first answer
#     768     """
# --> 769     ans, _ = srp(*args, **kargs)
#     770     if len(ans) > 0:
#     771         return cast(Packet, ans[0][1])
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/sendrecv.py:756, in srp(x, promisc, iface, iface_hint, filter, nofilter, type, *args, **kargs)
#     754     iface = conf.route.route(iface_hint)[0]
#     755 iface = resolve_iface(iface or conf.iface)
# --> 756 s = iface.l2socket()(promisc=promisc, iface=iface,
#     757                      filter=filter, nofilter=nofilter, type=type)
#     758 result = sndrcv(s, x, *args, **kargs)
#     759 s.close()
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/arch/linux/__init__.py:218, in L2Socket.__init__(self, iface, type, promisc, filter, nofilter, monitor)
#     216 self.type = type
#     217 self.promisc = conf.sniff_promisc if promisc is None else promisc
# --> 218 self.ins = socket.socket(
#     219     socket.AF_PACKET, socket.SOCK_RAW, socket.htons(type))
#     220 self.ins.setsockopt(socket.SOL_SOCKET, socket.SO_RCVBUF, 0)
#     221 if not nofilter:
#
# File ~/miniconda3/envs/ensia/lib/python3.14/socket.py:236, in socket.__init__(self, family, type, proto, fileno)
#     234     if proto == -1:
#     235         proto = 0
# --> 236 _socket.socket.__init__(self, family, type, proto, fileno)
#     237 self._io_refs = 0
#     238 self._closed = False
#
# PermissionError: [Errno 1] Operation not permitted

# %%
# sniff packets and display only arp packets
print ("Listening for arp packets ...")
sniff (filter="arp", count=5, prn=lambda pkt:pkt.summary())
# Out:
# Listening for arp packets ...
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 3
#       1 # sniff packets and display only arp packets
#       2 print ("Listening for arp packets ...")
# ----> 3 sniff (filter="arp", count=5, prn=lambda pkt:pkt.summary())
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/sendrecv.py:1424, in sniff(*args, **kwargs)
#    1420 @conf.commands.register
#    1421 def sniff(*args, **kwargs):
#    1422     # type: (*Any, **Any) -> PacketList
#    1423     sniffer = AsyncSniffer()
# -> 1424     sniffer._run(*args, **kwargs)
#    1425     return cast(PacketList, sniffer.results)
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/sendrecv.py:1273, in AsyncSniffer._run(self, count, store, offline, quiet, prn, lfilter, L2socket, timeout, opened_socket, stop_filter, iface, started_callback, session, chainCC, **karg)
#    1271     else:
#    1272         iface = iface or conf.iface
# -> 1273         sniff_sockets[_RL2(iface)(type=ETH_P_ALL, iface=iface,
#    1274                                   **karg)] = iface
#    1276 # Get select information from the sockets
#    1277 _main_socket = next(iter(sniff_sockets))
#
# File ~/miniconda3/envs/ensia/lib/python3.14/site-packages/scapy/arch/linux/__init__.py:218, in L2Socket.__init__(self, iface, type, promisc, filter, nofilter, monitor)
#     216 self.type = type
#     217 self.promisc = conf.sniff_promisc if promisc is None else promisc
# --> 218 self.ins = socket.socket(
#     219     socket.AF_PACKET, socket.SOCK_RAW, socket.htons(type))
#     220 self.ins.setsockopt(socket.SOL_SOCKET, socket.SO_RCVBUF, 0)
#     221 if not nofilter:
#
# File ~/miniconda3/envs/ensia/lib/python3.14/socket.py:236, in socket.__init__(self, family, type, proto, fileno)
#     234     if proto == -1:
#     235         proto = 0
# --> 236 _socket.socket.__init__(self, family, type, proto, fileno)
#     237 self._io_refs = 0
#     238 self._closed = False
#
# PermissionError: [Errno 1] Operation not permitted
